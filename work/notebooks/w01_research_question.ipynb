# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose the **Growth Recovery Forecasting System** lane because it focuses on predicting which pages are likely to lose organic performance before the decline becomes significant, allowing proactive optimization instead of reactive fixes. This aligns with my interest in using machine learning to support real business decisions rather than just analyzing historical data. It also provides an opportunity to apply sound ML principles—such as defining features from historical information only, avoiding data leakage, and building models that produce actionable predictions for content and SEO teams.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The decision my work improves is **which content pages should be prioritized for recovery before they experience a significant decline in organic traffic**. The primary users of this system are SEO specialists, content strategists, and digital marketing teams, who can use the predictions to take proactive actions such as updating content, improving internal linking, or optimizing on-page SEO. A wrong recommendation has two possible costs: a **false positive** wastes valuable time and resources on pages that did not need intervention, while a **false negative** allows high-value pages to decline unnoticed, resulting in lost organic traffic, reduced user engagement, and potentially lower business revenue.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
from google.colab import drive

# Mount Google Drive to access files stored there
drive.mount('/content/drive')

# IMPORTANT: The 'FileNotFoundError' persists because the path below is likely incorrect.
# Replace 'your_full_path_to_file_in_drive.csv' with the actual full path to your CSV file
# within your Google Drive. For example, if your file is in 'My Drive/data/content_refresh_anonymized.csv',
# you would use '/content/drive/My Drive/data/content_refresh_anonymized.csv'
df = pd.read_csv('/content/drive/My Drive/content_refresh_anonymized.csv')

# Display the first few rows of the DataFrame to verify
print(df.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# ...

# %%
down_all = (df['trend_direction'] == 'down').sum()
down_with_demand = ((df['trend_direction'] == 'down') & (df['impressions_90d'] >= 100)).sum()

print(f"Total pages with a 'down' trend: {down_all}")
print(f"Pages with a 'down' trend and impressions_90d >= 100: {down_with_demand}")
# Out:
# Total pages with a 'down' trend: 16262
# Pages with a 'down' trend and impressions_90d >= 100: 13152

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# What I can claim :
#
# "In this dataset, pages with low freshness, low CTR relative to their position tier, and thin word count are associated with declining engagement. This is an observed, directional pattern from a single anonymized snapshot — not proof that any individual page is declining, and not evidence of why a decline is happening. It can help prioritize which pages a reviewer looks at first, given limited review capacity — not a guarantee that reviewing or refreshing a flagged page will cause it to recover."
#
# What I cannot claim :
#
# "I cannot claim that this analysis 'proves' declining behavior, and I cannot claim to predict a specific page's decline over a future window. The starter dataset is a single snapshot with no timestamped history, so there is no way to validate a forward-looking prediction yet — that requires the warehouse's daily fact table and a proper time-based train/test split, which is planned for a later stage of this project, not this notebook."

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
